# %%
import pandas as pd
import numpy as np

# %%
import json
import os

kaggle_token = {
    "username": "zeeshanahmad406",  # <-- yahan apna Kaggle username likho
    "key": "KGAT_be94421001c21e8198108689e3b816a1"  # <-- yahan apna new API token
}

os.makedirs('/root/.kaggle', exist_ok=True)

with open('/root/.kaggle/kaggle.json', 'w') as f:
    json.dump(kaggle_token, f)

# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.12/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle) (6.3.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2025.11.12)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.4.4)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from kaggle) (3.11)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle) (5.29.5)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.12/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.12/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from kaggle) (0.5.1)

# %%
# !kaggle datasets download -d clmentbisaillon/fake-and-real-news-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/clmentbisaillon/fake-and-real-news-dataset
# License(s): CC-BY-NC-SA-4.0
# Downloading fake-and-real-news-dataset.zip to /content
#   0% 0.00/41.0M [00:00<?, ?B/s]
# 100% 41.0M/41.0M [00:00<00:00, 1.08GB/s]

# %%
# !unzip fake-and-real-news-dataset.zip
# Out:
# Archive:  fake-and-real-news-dataset.zip
#   inflating: Fake.csv
#   inflating: True.csv

# %%
true = pd.read_csv('True.csv')
fake = pd.read_csv('Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %% [markdown]
# Creating a column name is label.

# %%
true['label'] = '1'
fake['label'] = '0'

# %%
news = pd.concat([true, fake], axis = 0)

# %%
news.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date label
# 0  December 31, 2017      1
# 1  December 29, 2017      1
# 2  December 31, 2017      1
# 3  December 30, 2017      1
# 4  December 29, 2017      1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news = news.drop(['title', 'subject', 'date'], axis = 1)

# %%
news.head()
# Out:
#                                                 text label
# 0  WASHINGTON (Reuters) - The head of a conservat...     1
# 1  WASHINGTON (Reuters) - Transgender people will...     1
# 2  WASHINGTON (Reuters) - The special counsel inv...     1
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...     1
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...     1

# %% [markdown]
# **Reshuffling**
# Reshuffle the dataset.

# %%
news = news.sample(frac = 1)

# %%
news.head()
# Out:
#                                                     text label
# 6470   (Reuters) - U.S. President-elect Donald Trump’...     1
# 6668   TOKYO (Reuters) - The Kremlin said on Friday t...     1
# 16576  Swiss voters are deciding whether they want to...     0
# 11515  FLASHBACK: HILLARY CLINTON S STATE DEPARTMENT ...     0
# 9390   (Reuters) - Melissa Gilbert, best known for pl...     1

# %% [markdown]
# Reset the index

# %%
news.reset_index(inplace = True)

# %%
news.head()
# Out:
#    index                                               text label
# 0   6470  (Reuters) - U.S. President-elect Donald Trump’...     1
# 1   6668  TOKYO (Reuters) - The Kremlin said on Friday t...     1
# 2  16576  Swiss voters are deciding whether they want to...     0
# 3  11515  FLASHBACK: HILLARY CLINTON S STATE DEPARTMENT ...     0
# 4   9390  (Reuters) - Melissa Gilbert, best known for pl...     1

# %% [markdown]
# Now drop the index column

# %%
news.drop(['index'], axis = 1, inplace = True)

# %%
news.head()
# Out:
#                                                 text label
# 0  (Reuters) - U.S. President-elect Donald Trump’...     1
# 1  TOKYO (Reuters) - The Kremlin said on Friday t...     1
# 2  Swiss voters are deciding whether they want to...     0
# 3  FLASHBACK: HILLARY CLINTON S STATE DEPARTMENT ...     0
# 4  (Reuters) - Melissa Gilbert, best known for pl...     1

# %%
import re

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub(r'[^0-9a-zA-Z]', ' ', text)
    text  = re.sub(r'https?://\S+|www\.\S+', ' ', text)
    text = re.sub(r'\n', ' ', text)
    text = re.sub(r'<[^>]*>', ' ', text)
    text = re.sub(r'[^\w\s]', ' ', text)
    text = re.sub(r'\d+', ' ', text)
    text = re.sub(r'\n', ' ', text)
    return text

# %%
news['text'] = news['text'].apply(wordopt)

# %%
news['text']
# Out:
# 0         reuters    u s  president elect donald trump ...
# 1        tokyo  reuters    the kremlin said on friday t...
# 2        swiss voters are deciding whether they want to...
# 3        flashback  hillary clinton s state department ...
# 4         reuters    melissa gilbert  best known for pl...
#                                ...
# 44893    donald trump gets a lot of attention for his o...
# 44894    moscow  reuters    russia will supply turkey w...
# 44895    washington  reuters    a closely divided supre...
# 44896    pristina  reuters    two kosovo men pleaded gu...
# 44897    with marriage equality nationwide  and with mo...
# Name: text, Length: 44898, dtype: object

# %%
x = news['text']
y = news['label']

# %%
x
# Out:
# 0         reuters    u s  president elect donald trump ...
# 1        tokyo  reuters    the kremlin said on friday t...
# 2        swiss voters are deciding whether they want to...
# 3        flashback  hillary clinton s state department ...
# 4         reuters    melissa gilbert  best known for pl...
#                                ...
# 44893    donald trump gets a lot of attention for his o...
# 44894    moscow  reuters    russia will supply turkey w...
# 44895    washington  reuters    a closely divided supre...
# 44896    pristina  reuters    two kosovo men pleaded gu...
# 44897    with marriage equality nationwide  and with mo...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        1
# 2        0
# 3        0
# 4        1
#         ..
# 44893    0
# 44894    1
# 44895    1
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
x_train.shape
# Out:
# (31428,)

# %%
y_test.shape
# Out:
# (13470,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
xv_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 6465097 stored elements and shape (31428, 100157)>

# %%
xv_test
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 2756302 stored elements and shape (13470, 100157)>

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9878990348923534

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7010
#            1       0.99      0.99      0.99      6460
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()
DTC.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc = DTC.predict(xv_test)

# %%
DTC.score(xv_test, y_test)
# Out:
# 0.9962138084632517

# %%
print(classification_report(y_test, pred_dtc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      7010
#            1       1.00      1.00      1.00      6460
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=0)
rfc.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
predict_rfc = rfc.predict(xv_test)

# %%
rfc.score(xv_test, y_test)
# Out:
# 0.9882702301410542

# %%
print(classification_report(y_test, predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7010
#            1       0.99      0.99      0.99      6460
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier()
gbc.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier()

# %%
pred_gbc = gbc.predict(xv_test)

# %%
gbc.score(xv_test, y_test)
# Out:
# 0.99547141796585

# %%
print(classification_report(y_test, pred_gbc))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      7010
#            1       0.99      1.00      1.00      6460
#
#     accuracy                           1.00     13470
#    macro avg       1.00      1.00      1.00     13470
# weighted avg       1.00      1.00      1.00     13470
